# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/drive/MyDrive/DataScience/RetoChampions/Data/'

# %%
df = pd.read_csv(path+'ChampionsLeague2021Stats.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df = df.set_index(['Team'])
df.head()

# %%
df.info()

# %%
df.isna().sum()

# %%
corr_df = df.corr(method='pearson')

plt.figure(figsize=(10, 10))
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
corr_df.style.background_gradient(cmap='coolwarm')

# %%
goals_df = df[['Total goals','Total goals against','Goal difference']]

# %%
goals_df.head()

# %%
goals_df.info()

# %%
axes = goals_df.plot.barh(rot=0, subplots=True, figsize=(8,8))

# %%
goaltype_df = df[['Left foot', 'Right foot', 'Header', 'Inside area', 'Outside area', 'Penalties']]
goaltype_df

# %%
axes = goaltype_df.plot.barh(rot=0, subplots=True, figsize=(10,12))

# %%
attempts_df = df[['Total attempts',	'Average per game'	, 'Attempts on target',	'Attempts off target',	'Attempts blocked',	'Attempts against woodwork'	]]

# %%
attempts_df.head()

# %%
axes = attempts_df.iloc[:,0].plot.barh(rot=0, subplots=True, figsize=(6,4))

# %%
axes = attempts_df.iloc[:,1:].plot.barh(rot=0, subplots=True, figsize=(10,12))

# %%
passes_df = df[['PA',	'PC', 'PC %',	'Average ball possession (%)',	'Average ball possession (time)']]
passes_df.info()
